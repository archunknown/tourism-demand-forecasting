# %% [markdown]
# # Fase 1: Data Ingestion & Cleaning
# ## Sistema de Predicción de Demanda Turística y Precios Dinámicos
#
# En este cuaderno realizamos la extracción, limpieza y consolidación de las tres fuentes oficiales del MINCETUR (sitios turísticos, turismo emisivo y turismo receptivo) junto a la serie climatológica histórica obtenida vía API REST de Open-Meteo.

# %%
# Cargamos las librerías principales del entorno
import os
import sys
import pandas as pd

# Añadimos la carpeta 'src' al path para poder importar nuestros módulos locales
sys.path.append(os.path.abspath('../src'))
from utils_climate import obtener_clima_historico
from ingestion import ejecutar_pipeline_ingestion

print("Librerías e infraestructura cargadas correctamente.")
# Out:
# Librerías e infraestructura cargadas correctamente.

# %% [markdown]
# ### 1. Ejecución del Pipeline Automatizado de Ingestión

# %%
# Ejecutamos el pipeline completo definido en src/ingestion.py
df_consolidado = ejecutar_pipeline_ingestion()
df_consolidado.head(10)
# Out:
# === INICIANDO FASE 1: INGESTION Y LIMPIEZA DE DATOS ===
# Procesando datasets del MINCETUR...
# Consultando clima histórico desde API Open-Meteo...
# ¡Éxito! Dataset consolidado generado correctamente en:
#  -> C:\Users\ADMIN\tourism-demand-forecasting\data\processed\datos_consolidados_limpios.csv
#  -> Filas totales: 84 (84 meses de Enero 2019 a Diciembre 2025)
#        fecha  ANIO  ID_MES  demanda_total  visitantes_sitios_total  \
# 0 2019-01-01  2019       1      2224275.0                1848012.0
# 1 2019-02-01  2019       2      1934306.0                1582765.0
# 2 2019-03-01  2019       3      1735683.0                1360879.0
# 3 2019-04-01  2019       4      2053211.0                1692320.0
# 4 2019-05-01  2019       5      1945199.0                1585162.0
# 5 2019-06-01  2019       6      2062426.0                1708820.0
# 6 2019-07-01  2019       7      2626772.0                2214357.0
# 7 2019-08-01  2019       8      2627483.0                2245912.0
# ...

# %% [markdown]
# ### 2. Inspección y Resumen Estadístico del Dataset Consolidado

# %%
# Revisamos la información general de tipos de datos y nulos
df_consolidado.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   fecha                     84 non-null     datetime64[us]
#  1   ANIO                      84 non-null     int64
#  2   ID_MES                    84 non-null     int64
#  3   demanda_total             84 non-null     float64
#  4   visitantes_sitios_total   84 non-null     float64
#  5   turistas_receptivo_total  84 non-null     int64
#  6   turistas_emisivo_total    84 non-null     float64
#  7   temp_mean                 84 non-null     float32
#  8   temp_max                  84 non-null     float32
#  9   temp_min                  84 non-null     float32
#  10  precipitacion             84 non-null     float32
# dtypes: datetime64[us](1), float32(4), float64(3), int64(3)
# memory usage: 6.0 KB

# %%
# Mostramos el resumen estadístico de las variables consolidadas
df_consolidado.describe()
# Out:
#                             fecha         ANIO     ID_MES  demanda_total  \
# count                          84    84.000000  84.000000   8.400000e+01
# mean   2022-06-16 14:17:08.571428  2022.000000   6.500000   1.451351e+06
# min           2019-01-01 00:00:00  2019.000000   1.000000   0.000000e+00
# 25%           2020-09-23 12:00:00  2020.000000   3.750000   1.022480e+06
# 50%           2022-06-16 00:00:00  2022.000000   6.500000   1.654340e+06
# 75%           2024-03-08 18:00:00  2024.000000   9.250000   1.977430e+06
# max           2025-12-01 00:00:00  2025.000000  12.000000   2.627483e+06
# std                           NaN     2.012012   3.472786   7.337691e+05
#
#        visitantes_sitios_total  turistas_receptivo_total  \
# count             8.400000e+01                 84.000000
# mean              1.249926e+06             201425.369048
# min               0.000000e+00                  0.000000
# 25%               9.307018e+05              72461.250000
# ...

# %% [markdown]
# ### 3. Conclusión de la Fase 1
# Se ha generado exitosamente el archivo `data/processed/datos_consolidados_limpios.csv` con **84 registros mensuales** (Enero 2019 a Diciembre 2025). El dataset se encuentra 100% validado y listo para ser entregado a la **Fase 2: Exploratory Data Analysis (EDA)**.
